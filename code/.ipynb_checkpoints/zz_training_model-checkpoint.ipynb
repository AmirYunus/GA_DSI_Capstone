# %% [markdown]
# <h1>TECHNICAL REPORT - FINANCIAL FORENSIC DATA ANALYSIS<span class="tocSkip"></span></h1>

# %% [markdown]
# Author: Amir Yunus<br>
# GitHub: https://github.com/AmirYunus/GA_DSI_Capstone
# ***

# %% [markdown]
# # PREFACE

# %% [markdown]
# ## Background: Fraud and the Accounting System

# %% [markdown]
# The Association of Certified Fraud Examiners estimates in its Global Study on Occupational Fraud and Abuse, 2018 [[1]](../documents/2018-report-to-the-nations.pdf) that organisations lose 5% of their annual revenues to fraud. In their report, the term **"occupational fraud"** refers to,
#
# >_" . . . an attack against the organisation from within, by the very people who were entrusted to protect its assets and resources"_.
#
# A similar study, conducted by the auditors of PwC [[2]](../documents/global-economic-crime-and-fraud-survey-2018.pdf), revealed that 30% of the study respondents experienced losses of between USD 100,000 and USD 5 million in the last 24 months (as of 2018). The study also showed that financial statement fraud caused by far the greatest median loss of the surveyed fraud schemes.
#
# At the same time organizations accelerate the digitisation and reconfiguration of business processes [[3]](../documents/accelerating_the_digitization_of_business_processes.pdf) affecting in particular Accounting Information Systems (AIS) or more general Enterprise Resource Planning (ERP) systems.

# %% [markdown]
# ## Classification of Financial Anomalies

# %% [markdown]
# ## Content

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#PREFACE" data-toc-modified-id="PREFACE-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>PREFACE</a></span><ul class="toc-item"><li><span><a href="#Background:-Fraud-and-the-Accounting-System" data-toc-modified-id="Background:-Fraud-and-the-Accounting-System-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Background: Fraud and the Accounting System</a></span></li><li><span><a href="#Classification-of-Financial-Anomalies" data-toc-modified-id="Classification-of-Financial-Anomalies-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Classification of Financial Anomalies</a></span></li><li><span><a href="#Content" data-toc-modified-id="Content-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Content</a></span></li><li><span><a href="#Data-Dictionary" data-toc-modified-id="Data-Dictionary-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Data Dictionary</a></span></li><li><span><a href="#Libraries" data-toc-modified-id="Libraries-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Libraries</a></span></li><li><span><a href="#Functions" data-toc-modified-id="Functions-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Functions</a></span></li></ul></li><li><span><a href="#ABOUT-THE-DATASET" data-toc-modified-id="ABOUT-THE-DATASET-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>ABOUT THE DATASET</a></span><ul class="toc-item"><li><span><a href="#Importing-the-Dataset" data-toc-modified-id="Importing-the-Dataset-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Importing the Dataset</a></span></li></ul></li><li><span><a href="#EXPLORATORY-DATA-ANALYSIS" data-toc-modified-id="EXPLORATORY-DATA-ANALYSIS-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>EXPLORATORY DATA ANALYSIS</a></span><ul class="toc-item"><li><span><a href="#Remove-Label" data-toc-modified-id="Remove-Label-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Remove Label</a></span></li><li><span><a href="#Categorical-Features" data-toc-modified-id="Categorical-Features-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Categorical Features</a></span></li><li><span><a href="#Numerical-Features" data-toc-modified-id="Numerical-Features-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Numerical Features</a></span></li><li><span><a href="#Merge-Features" data-toc-modified-id="Merge-Features-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Merge Features</a></span></li></ul></li><li><span><a href="#Adversarial-Autoencoder-Neural-Network" data-toc-modified-id="Adversarial-Autoencoder-Neural-Network-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Adversarial Autoencoder Neural Network</a></span><ul class="toc-item"><li><span><a href="#AAE-Implementation---Encoder-$q_{\theta}(z|x)$" data-toc-modified-id="AAE-Implementation---Encoder-$q_{\theta}(z|x)$-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>AAE Implementation - Encoder $q_{\theta}(z|x)$</a></span></li><li><span><a href="#AAE-Implementation---Decoder-$p_{\theta}(x|z)$" data-toc-modified-id="AAE-Implementation---Decoder-$p_{\theta}(x|z)$-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>AAE Implementation - Decoder $p_{\theta}(x|z)$</a></span></li><li><span><a href="#AAE-Implementation---Discriminator-Network-$d_{\theta}(z)$" data-toc-modified-id="AAE-Implementation---Discriminator-Network-$d_{\theta}(z)$-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>AAE Implementation - Discriminator Network $d_{\theta}(z)$</a></span><ul class="toc-item"><li><span><a href="#Adversarial-Autoencoder-Neural-Network-Training" data-toc-modified-id="Adversarial-Autoencoder-Neural-Network-Training-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Adversarial Autoencoder Neural Network Training</a></span><ul class="toc-item"><li><span><a href="#Reconstruction-Phase-Parameter" data-toc-modified-id="Reconstruction-Phase-Parameter-4.3.1.1"><span class="toc-item-num">4.3.1.1&nbsp;&nbsp;</span>Reconstruction Phase Parameter</a></span></li><li><span><a href="#Regularization-Phase-Parameter" data-toc-modified-id="Regularization-Phase-Parameter-4.3.1.2"><span class="toc-item-num">4.3.1.2&nbsp;&nbsp;</span>Regularization Phase Parameter</a></span></li></ul></li><li><span><a href="#Creation-of-the-Imposed-Latent-Prior-Distribution-$p(z)$" data-toc-modified-id="Creation-of-the-Imposed-Latent-Prior-Distribution-$p(z)$-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Creation of the Imposed Latent Prior Distribution $p(z)$</a></span></li></ul></li><li><span><a href="#Training-the-Adversarial-Autoencoder-Neural-Network-(AAE)-Model" data-toc-modified-id="Training-the-Adversarial-Autoencoder-Neural-Network-(AAE)-Model-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Training the Adversarial Autoencoder Neural Network (AAE) Model</a></span><ul class="toc-item"><li><span><a href="#Preparing-the-Network-Training-Data" data-toc-modified-id="Preparing-the-Network-Training-Data-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Preparing the Network Training Data</a></span></li><li><span><a href="#Running-the-Network-Training" data-toc-modified-id="Running-the-Network-Training-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Running the Network Training</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# ## Libraries

# %%
# import utilities
import os, sys, random, io, urllib, csv
import IPython
from datetime import datetime

# import data science libraries
import pandas as pd
import random as rd
import numpy as np

# import pytorch libraries
import torch
import shutil
import torch.optim as optim
from torch import nn
from torch.utils.data import DataLoader

# import python plotting libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Functions

# %%
# %autosave 60
# Out:
# Autosaving every 60 seconds

# %%
nl = "\n"

# %%
def log ():
    now = str(datetime.now())
    print(f'[LOG {now}]')
    return

# %%
def save_checkpoint(state, filename='../checkpoint/checkpoint.pth.tar'):
    log()
    print("=> Saving checkpoint...")
    torch.save(state, filename) # save checkpoint
    print("Saved")

# %%
def load_ckp(checkpoint_fpath, model, optimzer):
    checkpoint = torch.load(checkpoint_fpath)
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    return model, optimzer, checkpoint['epoch']

# %%
# define encoder class
class Encoder(nn.Module):

    # define class constructor
    def __init__(self, input_size, hidden_size):

        # call super class constructor
        super(Encoder, self).__init__()

        # specify first layer - in 618, out 256
        self.map_L1 = nn.Linear(input_size, hidden_size[0], bias=True) # init linearity
        nn.init.xavier_uniform_(self.map_L1.weight) # init weights according to [9]
        nn.init.constant_(self.map_L1.bias, 0.0) # constant initialization of the bias
        self.map_R1 = nn.LeakyReLU(negative_slope=0.4, inplace=True) # add non-linearity according to [10]

        # specify second layer - in 256, out 64
        self.map_L2 = nn.Linear(hidden_size[0], hidden_size[1], bias=True)
        nn.init.xavier_uniform_(self.map_L2.weight)
        nn.init.constant_(self.map_L2.bias, 0.0)
        self.map_R2 = nn.LeakyReLU(negative_slope=0.4, inplace=True)

        # specify third layer - in 64, out 16
        self.map_L3 = nn.Linear(hidden_size[1], hidden_size[2], bias=True)
        nn.init.xavier_uniform_(self.map_L3.weight)
        nn.init.constant_(self.map_L3.bias, 0.0)
        self.map_R3 = nn.LeakyReLU(negative_slope=0.4, inplace=True)

        # specify fourth layer - in 16, out 4
        self.map_L4 = nn.Linear(hidden_size[2], hidden_size[3], bias=True)
        nn.init.xavier_uniform_(self.map_L4.weight)
        nn.init.constant_(self.map_L4.bias, 0.0)
        self.map_R4 = nn.LeakyReLU(negative_slope=0.4, inplace=True)

        # specify fifth layer - in 4, out 2
        self.map_L5 = nn.Linear(hidden_size[3], hidden_size[4], bias=True)
        nn.init.xavier_uniform_(self.map_L5.weight)
        nn.init.constant_(self.map_L5.bias, 0.0)
        self.map_R5 = torch.nn.LeakyReLU(negative_slope=0.4, inplace=True)
        
    # define forward pass
    def forward(self, x):

        # run forward pass through the network
        x = self.map_R1(self.map_L1(x))
        x = self.map_R2(self.map_L2(x))
        x = self.map_R3(self.map_L3(x))
        x = self.map_R4(self.map_L4(x))
        x = self.map_R5(self.map_L5(x))

        # return result
        return x

# %%
# define decoder class
class Decoder(nn.Module):

    # define class constructor
    def __init__(self, output_size, hidden_size):

        # call super class constructor
        super(Decoder, self).__init__()

        # specify first layer - in 2, out 4
        self.map_L1 = nn.Linear(hidden_size[0], hidden_size[1], bias=True) # init linearity
        nn.init.xavier_uniform_(self.map_L1.weight) # init weights according to [9]
        nn.init.constant_(self.map_L1.bias, 0.0) # constant initialization of the bias
        self.map_R1 = nn.LeakyReLU(negative_slope=0.4, inplace=True) # add non-linearity according to [10]

        # specify second layer - in 4, out 16
        self.map_L2 = nn.Linear(hidden_size[1], hidden_size[2], bias=True)
        nn.init.xavier_uniform_(self.map_L2.weight)
        nn.init.constant_(self.map_L2.bias, 0.0)
        self.map_R2 = nn.LeakyReLU(negative_slope=0.4, inplace=True)

        # specify third layer - in 16, out 64
        self.map_L3 = nn.Linear(hidden_size[2], hidden_size[3], bias=True)
        nn.init.xavier_uniform_(self.map_L3.weight)
        nn.init.constant_(self.map_L3.bias, 0.0)
        self.map_R3 = nn.LeakyReLU(negative_slope=0.4, inplace=True)

        # specify fourth layer - in 64, out 256
        self.map_L4 = nn.Linear(hidden_size[3], hidden_size[4], bias=True)
        nn.init.xavier_uniform_(self.map_L4.weight)
        nn.init.constant_(self.map_L4.bias, 0.0)
        self.map_R4 = nn.LeakyReLU(negative_slope=0.4, inplace=True)
        
        # specify fifth layer - in 256, out 618
        self.map_L5 = nn.Linear(hidden_size[4], output_size, bias=True)
        nn.init.xavier_uniform_(self.map_L5.weight)
        nn.init.constant_(self.map_L5.bias, 0.0)
        self.map_S5 = torch.nn.Sigmoid()

    # define forward pass
    def forward(self, x):

        # run forward pass through the network
        x = self.map_R1(self.map_L1(x))
        x = self.map_R2(self.map_L2(x))
        x = self.map_R3(self.map_L3(x))
        x = self.map_R4(self.map_L4(x))
        x = self.map_S5(self.map_L5(x))

        # return result
        return x

# %%
# define discriminator class
class Discriminator(nn.Module):

    # define class constructor
    def __init__(self, input_size, hidden_size, output_size):

        # call super class constructor
        super(Discriminator, self).__init__()

        # specify first layer - in 2, out 256
        self.map_L1 = nn.Linear(input_size, hidden_size[0], bias=True) # init linearity
        nn.init.xavier_uniform_(self.map_L1.weight) # init weights according to [9]
        nn.init.constant_(self.map_L1.bias, 0.0) # constant initialization of the bias
        self.map_R1 = nn.LeakyReLU(negative_slope=0.4, inplace=True) # add non-linearity according to [10]

        # specify second layer - in 256, out 16
        self.map_L2 = nn.Linear(hidden_size[0], hidden_size[1], bias=True)
        nn.init.xavier_uniform_(self.map_L2.weight)
        nn.init.constant_(self.map_L2.bias, 0.0)
        self.map_R2 = nn.LeakyReLU(negative_slope=0.4, inplace=True)

        # specify third layer - in 16, out 4
        self.map_L3 = nn.Linear(hidden_size[1], hidden_size[2], bias=True)
        nn.init.xavier_uniform_(self.map_L3.weight)
        nn.init.constant_(self.map_L3.bias, 0.0)
        self.map_R3 = nn.LeakyReLU(negative_slope=0.4, inplace=True)
        
        # specify fourth layer - in 4, out 2
        self.map_L4 = nn.Linear(hidden_size[2], output_size, bias=True)
        nn.init.xavier_uniform_(self.map_L4.weight)
        nn.init.constant_(self.map_L4.bias, 0.0)
        self.map_S4 = torch.nn.Sigmoid()

    # define forward pass
    def forward(self, x):

        # run forward pass through the network
        x = self.map_R1(self.map_L1(x))
        x = self.map_R2(self.map_L2(x))
        x = self.map_R3(self.map_L3(x))
        x = self.map_S4(self.map_L4(x))

        # return result
        return x

# %%
# define euclidean distance calculation
def compute_euclid_distance(x, y):
    
    # calculate euclidean distance 
    euclidean_distance = np.sqrt(np.sum((x - y) ** 2, axis=1))
    
    # return euclidean distance
    return euclidean_distance

# %%
# init deterministic seed
seed_value = 1234
rd.seed(seed_value) # set random seed
np.random.seed(seed_value) # set numpy seed
torch.manual_seed(seed_value) # set pytorch seed CPU

# %%
if not os.path.exists('../data'): os.makedirs('../data')  # create data directory
if not os.path.exists('../models'): os.makedirs('../models')  # create trained models directory

# %% [markdown]
# # ABOUT THE DATASET

# %% [markdown]
# ## Importing the Dataset

# %%
log()
# load the dataset into the notebook kernel
ori_dataset = pd.read_csv('../data/fraud_dataset_v2.csv')
# inspect the datasets dimensionalities
print(F'Transactional dataset of {ori_dataset.shape[0]} rows and {ori_dataset.shape[1]} columns loaded')
# Out:
# [LOG 2019-11-08 20:57:11.006650]
# Transactional dataset of 533009 rows and 10 columns loaded

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ## Remove Label

# %%
# remove the "ground-truth" label information for the following steps of the lab
log()
label = ori_dataset.pop('label')
# Out:
# [LOG 2019-11-08 20:57:12.168718]

# %% [markdown]
# ## Categorical Features

# %%
# select categorical attributes to be "one-hot" encoded
log()

categorical_attr_names = ['KTOSL', 'PRCTR', 'BSCHL', 'HKONT', 'BUKRS', 'WAERS']

# encode categorical attributes into a binary one-hot encoded representation 
ori_dataset_categ_transformed = pd.get_dummies(ori_dataset[categorical_attr_names])
# Out:
# [LOG 2019-11-08 20:57:12.317616]

# %% [markdown]
# ## Numerical Features

# %%
# select "DMBTR" vs. "WRBTR" attribute
log()

numeric_attr_names = ['DMBTR', 'WRBTR']

# add a small epsilon to eliminate zero values from data for log scaling
numeric_attr = ori_dataset[numeric_attr_names] + 1e-7
numeric_attr = numeric_attr.apply(np.log)

# normalize all numeric attributes to the range [0,1]
ori_dataset_numeric_attr = (numeric_attr - numeric_attr.min()) / (numeric_attr.max() - numeric_attr.min())
# Out:
# [LOG 2019-11-08 20:57:15.048067]

# %% [markdown]
# ## Merge Features

# %%
# merge categorical and numeric subsets
ori_subset_transformed = pd.concat([ori_dataset_categ_transformed, ori_dataset_numeric_attr], axis = 1)
# inspect final dimensions of pre-processed transactional data
log ()
ori_subset_transformed.shape
# Out:
# [LOG 2019-11-08 20:57:16.278123]
# (533009, 618)

# %% [markdown]
# # Adversarial Autoencoder Neural Network

# %% [markdown]
# ## AAE Implementation - Encoder $q_{\theta}(z|x)$

# %%
log()
# init training network classes / architectures
encoder_train = Encoder(input_size=ori_subset_transformed.shape[1], hidden_size=[256, 64, 16, 4, 2])

print(f'Encoder Architecture:\n\n{encoder_train}')
# Out:
# [LOG 2019-11-08 20:57:16.291088]
# Encoder Architecture:
#
# Encoder(
#   (map_L1): Linear(in_features=618, out_features=256, bias=True)
#   (map_R1): LeakyReLU(negative_slope=0.4, inplace=True)
#   (map_L2): Linear(in_features=256, out_features=64, bias=True)
#   (map_R2): LeakyReLU(negative_slope=0.4, inplace=True)
#   (map_L3): Linear(in_features=64, out_features=16, bias=True)
#   (map_R3): LeakyReLU(negative_slope=0.4, inplace=True)
#   (map_L4): Linear(in_features=16, out_features=4, bias=True)
#   (map_R4): LeakyReLU(negative_slope=0.4, inplace=True)
#   (map_L5): Linear(in_features=4, out_features=2, bias=True)
#   (map_R5): LeakyReLU(negative_slope=0.4, inplace=True)
# )

# %% [markdown]
# ## AAE Implementation - Decoder $p_{\theta}(x|z)$

# %%
log()
# init training network classes / architectures
decoder_train = Decoder(output_size=ori_subset_transformed.shape[1], hidden_size=[2, 4, 16, 64, 256])

print(f'Decoder Architecture:\n\n{decoder_train}')
# Out:
# [LOG 2019-11-08 20:57:16.773424]
# Decoder Architecture:
#
# Decoder(
#   (map_L1): Linear(in_features=2, out_features=4, bias=True)
#   (map_R1): LeakyReLU(negative_slope=0.4, inplace=True)
#   (map_L2): Linear(in_features=4, out_features=16, bias=True)
#   (map_R2): LeakyReLU(negative_slope=0.4, inplace=True)
#   (map_L3): Linear(in_features=16, out_features=64, bias=True)
#   (map_R3): LeakyReLU(negative_slope=0.4, inplace=True)
#   (map_L4): Linear(in_features=64, out_features=256, bias=True)
#   (map_R4): LeakyReLU(negative_slope=0.4, inplace=True)
#   (map_L5): Linear(in_features=256, out_features=618, bias=True)
#   (map_S5): Sigmoid()
# )

# %% [markdown]
# ## AAE Implementation - Discriminator Network $d_{\theta}(z)$

# %%
log()
# init training network classes / architectures
discriminator_train = Discriminator(input_size=2, hidden_size=[256, 16, 4, 2], output_size=1)

print(f'Discriminator Architecture:\n\n{discriminator_train}')
# Out:
# [LOG 2019-11-08 20:57:16.906419]
# Discriminator Architecture:
#
# Discriminator(
#   (map_L1): Linear(in_features=2, out_features=256, bias=True)
#   (map_R1): LeakyReLU(negative_slope=0.4, inplace=True)
#   (map_L2): Linear(in_features=256, out_features=16, bias=True)
#   (map_R2): LeakyReLU(negative_slope=0.4, inplace=True)
#   (map_L3): Linear(in_features=16, out_features=4, bias=True)
#   (map_R3): LeakyReLU(negative_slope=0.4, inplace=True)
#   (map_L4): Linear(in_features=4, out_features=1, bias=True)
#   (map_S4): Sigmoid()
# )

# %% [markdown]
# ### Adversarial Autoencoder Neural Network Training

# %% [markdown]
# #### Reconstruction Phase Parameter

# %%
log()
# define the optimization criterion / loss function
reconstruction_criterion_categorical = nn.BCELoss(reduction='mean')
reconstruction_criterion_numeric = nn.MSELoss(reduction='mean')
# Out:
# [LOG 2019-11-08 20:57:17.040604]

# %%
log()
# define encoder and decoded learning rate
learning_rate_enc = 1e-3
learning_rate_dec = 1e-3

# define encoder and decoder optimization strategy
encoder_optimizer = optim.Adam(encoder_train.parameters(), lr=learning_rate_enc)
decoder_optimizer = optim.Adam(decoder_train.parameters(), lr=learning_rate_dec)
# Out:
# [LOG 2019-11-08 20:57:17.162689]

# %% [markdown]
# #### Regularization Phase Parameter

# %%
log()
# init the discriminator losses
discriminator_criterion = nn.BCELoss()
# Out:
# [LOG 2019-11-08 20:57:17.284407]

# %%
log()
# define generator and discriminator learning rate
learning_rate_dis_z = 1e-5

# define generator and discriminator optimization strategy
discriminator_optimizer = optim.Adam(discriminator_train.parameters(), lr=learning_rate_dis_z)
# Out:
# [LOG 2019-11-08 20:57:17.418054]

# %% [markdown]
# ### Creation of the Imposed Latent Prior Distribution $p(z)$

# %%
log()
# define the number of gaussians
tau = 5 

# define radius of each gaussian
radius = 0.8

# define the sigma of each gaussian
sigma = 0.01

# define the dimensionality of each gaussian
dim = 2

# determine x and y coordinates of the target mixture of gaussians
x_centroid = (radius * np.sin(np.linspace(0, 2 * np.pi, tau, endpoint=False)) + 1) / 2
y_centroid = (radius * np.cos(np.linspace(0, 2 * np.pi, tau, endpoint=False)) + 1) / 2

# determine each gaussians mean (centroid) and standard deviation
mu_gauss = np.vstack([x_centroid, y_centroid]).T

# determine the number of samples to be created per gaussian
samples_per_gaussian = 100000

# iterate over the number of distinct gaussians
for i, mu in enumerate(mu_gauss):

    # case: first gaussian
    if i == 0:

        # randomly sample from gaussion distribution 
        z_continous_samples_all = np.random.normal(mu, sigma, size=(samples_per_gaussian, dim))

    # case: non-first gaussian
    else:

        # randomly sample from gaussian distribution
        z_continous_samples = np.random.normal(mu, sigma, size=(samples_per_gaussian, dim))

        # collect and stack new samples
        z_continous_samples_all = np.vstack([z_continous_samples_all, z_continous_samples])
# Out:
# [LOG 2019-11-08 20:57:17.540691]

# %% [markdown]
# ## Training the Adversarial Autoencoder Neural Network (AAE) Model

# %% [markdown]
# ### Preparing the Network Training Data

# %%
log()
# specify training parameters
num_epochs = 500
start_epoch = 0
mini_batch_size = 128
# Out:
# [LOG 2019-11-08 20:57:17.657378]

# %%
log()
# convert pre-processed data to pytorch tensor
torch_dataset = torch.from_numpy(ori_subset_transformed.values).float()

# convert to pytorch tensor - none cuda enabled
dataloader = DataLoader(torch_dataset, batch_size=mini_batch_size, shuffle=True, num_workers=0)
# note: we set num_workers to zero to retrieve deterministic results
# Out:
# [LOG 2019-11-08 20:57:17.785004]

# %% [markdown]
# ### Running the Network Training

# %%
log()
# init collection of training losses
epoch_reconstruction_losses = []
epoch_discriminator_losses = []
epoch_generator_losses = []
# Out:
# [LOG 2019-11-08 20:57:23.152657]

# %%
log()
mini_batch_verbose_step = 1000
# Out:
# [LOG 2019-11-08 20:57:23.551615]

# %%
check_enc = "../checkpoint/checkpoint_enc.pth.tar"
check_dec = "../checkpoint/checkpoint_dec.pth.tar"
check_dis = "../checkpoint/checkpoint_dis.pth.tar"
check_rec_loss = "../checkpoint/checkpoint_rec_loss.csv"
check_dis_loss = "../checkpoint/checkpoint_dis_loss.csv"
check_gen_loss = "../checkpoint/checkpoint_gen_loss.csv"

if os.path.isfile(check_enc):
    log()
    print("Loading encoder checkpoint . . .")
    checkpoint = torch.load(check_enc,
                           map_location=torch.device('cpu'))
    start_epoch = checkpoint['epoch']
    encoder_train.load_state_dict(checkpoint['state_dict'])
    print(f"Loaded encoder checkpoint trained for {start_epoch:04} / {num_epochs:04}")

if os.path.isfile(check_dec):
    log()
    print("Loading decoder checkpoint . . .")
    checkpoint = torch.load(check_dec,
                           map_location=torch.device('cpu'))
    start_epoch = checkpoint['epoch']
    decoder_train.load_state_dict(checkpoint['state_dict'])
    print(f"Loaded decoder checkpoint trained for {start_epoch:04} / {num_epochs:04}")
    
if os.path.isfile(check_dis):
    log()
    print("Loading discriminator checkpoint . . .")
    checkpoint = torch.load(check_dis,
                           map_location=torch.device('cpu'))
    start_epoch = checkpoint['epoch']
    discriminator_train.load_state_dict(checkpoint['state_dict'])
    print(f"Loaded discriminator checkpoint trained for {start_epoch:04} / {num_epochs:04}")
    
if os.path.isfile(check_rec_loss):
    log()
    print("Loading reconstruction loss checkpoint . . .")
    with open(check_rec_loss, "r") as f:
        reader = csv.reader(f,quoting=csv.QUOTE_NONNUMERIC)
        tmp_list = list(reader)
        for i in tmp_list:
            epoch_reconstruction_losses.extend(i)
    print(f"Loaded reconstruction loss checkpoint for {(len(epoch_reconstruction_losses)):04} / {num_epochs:04}")

if os.path.isfile(check_dis_loss):
    log()
    print("Loading discriminator loss checkpoint . . .")
    with open(check_dis_loss, "r") as f:
        reader = csv.reader(f,quoting=csv.QUOTE_NONNUMERIC)
        tmp_list = list(reader)
        for i in tmp_list:
            epoch_discriminator_losses.extend(i)
    print(f"Loaded discriminator loss checkpoint for {(len(epoch_discriminator_losses)):04} / {num_epochs:04}")

if os.path.isfile(check_gen_loss):
    log()
    print("Loading generator loss checkpoint . . .")
    with open(check_gen_loss, "r") as f:
        reader = csv.reader(f,quoting=csv.QUOTE_NONNUMERIC)
        tmp_list = list(reader)
        for i in tmp_list:
            epoch_generator_losses.extend(i)
    print(f"Loaded generator loss checkpoint for {(len(epoch_generator_losses)):04} / {num_epochs:04}")

# %%
# initialize training adversarial autoencoder model
num_epochs = num_epochs - start_epoch

for epoch in range(num_epochs):

    # init mini batch counter
    mini_batch_count = 0
    
    # init epoch training losses
    batch_reconstruction_losses = 0.0
    batch_discriminator_losses = 0.0
    batch_generator_losses = 0.0

    # set networks in training mode (apply dropout when needed)
    encoder_train.train()
    decoder_train.train()
    discriminator_train.train()
    
    # start timer
    start_time = datetime.now()

    # iterate over epoch mini batches
    for mini_batch_data in dataloader:

        # increase mini batch counter
        mini_batch_count += 1
        
        # convert mini batch to torch variable
        mini_batch_torch = torch.FloatTensor(mini_batch_data)
        
        # reset the networks gradients
        encoder_train.zero_grad()
        decoder_train.zero_grad()
        discriminator_train.zero_grad()

        # =================== reconstruction phase =====================
        
        # run autoencoder encoding - decoding
        z_sample = encoder_train(mini_batch_torch)
        mini_batch_reconstruction = decoder_train(z_sample)

        # split input date to numerical and categorical part
        batch_cat = mini_batch_torch[:, :ori_dataset_categ_transformed.shape[1]]
        batch_num = mini_batch_torch[:, ori_dataset_categ_transformed.shape[1]:]
        
        # split reconstruction to numerical and categorical part
        rec_batch_cat = mini_batch_reconstruction[:, :ori_dataset_categ_transformed.shape[1]]
        rec_batch_num = mini_batch_reconstruction[:, ori_dataset_categ_transformed.shape[1]:]

        # backward pass + gradients update
        rec_error_cat = reconstruction_criterion_categorical(input=rec_batch_cat, target=batch_cat)  # one-hot attr error
        rec_error_num = reconstruction_criterion_numeric(input=rec_batch_num, target=batch_num)  # numeric attr error

        # combine both reconstruction errors
        reconstruction_loss = rec_error_cat + rec_error_num
        
        # run backward pass - determine gradients
        reconstruction_loss.backward()
        
        # collect batch reconstruction loss
        batch_reconstruction_losses += reconstruction_loss.item()
        
        # update network parameter - decoder and encoder
        decoder_optimizer.step()
        encoder_optimizer.step()

        # =================== regularization phase =====================
        # =================== discriminator training ===================

        # set discriminator in evaluation mode
        discriminator_train.eval()

        # generate target latent space data
        z_target_batch = z_continous_samples_all[random.sample(range(0, z_continous_samples_all.shape[0]), mini_batch_size),:]

        # convert to torch tensor
        z_target_batch = torch.FloatTensor(z_target_batch)

        # determine mini batch sample generated by the encoder -> fake gaussian sample
        z_fake_gauss = encoder_train(mini_batch_torch)

        # determine discriminator classification of both samples
        d_real_gauss = discriminator_train(z_target_batch) # real sampled gaussian 
        d_fake_gauss = discriminator_train(z_fake_gauss) # fake created gaussian

        # determine discriminator classification target variables
        d_real_gauss_target = torch.FloatTensor(torch.ones(d_real_gauss.shape)) # real -> 1
        d_fake_gauss_target = torch.FloatTensor(torch.zeros(d_fake_gauss.shape)) # fake -> 0

        # determine individual discrimination losses
        discriminator_loss_real = discriminator_criterion(target=d_real_gauss_target, input=d_real_gauss) # real loss
        discriminator_loss_fake = discriminator_criterion(target=d_fake_gauss_target, input=d_fake_gauss) # fake loss
        
        # add real loss and fake loss
        discriminator_loss = discriminator_loss_fake + discriminator_loss_real

        # run backward through the discriminator network
        discriminator_loss.backward()
        
        # collect discriminator loss
        batch_discriminator_losses += discriminator_loss.item()

        # update network the discriminator network parameters
        discriminator_optimizer.step()

        # reset the networks gradients
        encoder_train.zero_grad()
        decoder_train.zero_grad()
        discriminator_train.zero_grad()

        # =================== regularization phase =====================
        # =================== generator training =======================

        # set encoder / generator in training mode
        encoder_train.train()
        
        # reset the encoder / generator networks gradients
        encoder_train.zero_grad()

        # determine fake gaussian sample generated by the encoder / generator
        z_fake_gauss = encoder_train(mini_batch_torch)

        # determine discriminator classification of fake gaussian sample
        d_fake_gauss = discriminator_train(z_fake_gauss)

        # determine discriminator classification target variables
        d_fake_gauss_target = torch.FloatTensor(torch.ones(d_fake_gauss.shape)) # fake -> 1

        # determine discrimination loss of fake gaussian sample
        generator_loss = discriminator_criterion(target=d_fake_gauss_target, input=d_fake_gauss)
        
        # collect generator loss
        batch_generator_losses += generator_loss.item()

        # run backward pass - determine gradients
        generator_loss.backward()

        # update network paramaters - encoder / generatorc
        encoder_optimizer.step()

        # reset the networks gradients
        encoder_train.zero_grad()
        decoder_train.zero_grad()
        discriminator_train.zero_grad()

    # collect epoch training losses - reconstruction loss
    epoch_reconstruction_loss = batch_reconstruction_losses / mini_batch_count
    epoch_reconstruction_losses.extend([epoch_reconstruction_loss])
    
    # collect epoch training losses - discriminator loss
    epoch_discriminator_loss = batch_discriminator_losses / mini_batch_count
    epoch_discriminator_losses.extend([epoch_discriminator_loss])
    
    # collect epoch training losses - generator loss
    epoch_generator_loss = batch_generator_losses / mini_batch_count
    epoch_generator_losses.extend([epoch_generator_loss])
    
    # print epoch reconstruction loss
    log()
    print(f'Epoch {(start_epoch + epoch + 1):04} / {(num_epochs + start_epoch):04}:{nl}\
    Reconstruction Loss: {epoch_reconstruction_loss:.4f}{nl}\
    Discriminator Loss: {epoch_discriminator_loss:.4f}{nl}\
    Generator Loss: {epoch_generator_loss:.4f}{nl}\
    Time Taken: {datetime.now() - start_time}{nl}\
    {nl}\
    Saving checkpoint . . .')
    
    # =================== save model snapshots to disk ============================
    
    # save trained encoder model file to disk
    encoder_model_name = str(f"x{mini_batch_size}_ep_{(start_epoch + epoch + 1):04}_encoder_model.pth")
    torch.save(encoder_train.state_dict(), os.path.join("../models", encoder_model_name))
    torch.save({
        'epoch': start_epoch + epoch + 1,
        'state_dict': encoder_train.state_dict()
    }, check_enc)

    # save trained decoder model file to disk
    decoder_model_name = str(f"x{mini_batch_size}_ep_{(start_epoch + epoch + 1):04}_decoder_model.pth")
    torch.save(decoder_train.state_dict(), os.path.join("../models", decoder_model_name))
    torch.save({
        'epoch': start_epoch + epoch + 1,
        'state_dict': decoder_train.state_dict()
    }, check_dec)
    
    # save trained discriminator model file to disk
    decoder_model_name = str(f"x{mini_batch_size}_ep_{(start_epoch + epoch + 1):04}_discriminator_model.pth")
    torch.save(discriminator_train.state_dict(), os.path.join("../models", decoder_model_name))
    torch.save({
        'epoch': start_epoch + epoch + 1,
        'state_dict': discriminator_train.state_dict()
    }, check_dis)
    
    with open(check_rec_loss, "w") as output:
        writer = csv.writer(output, lineterminator='\n')
        for val in epoch_reconstruction_losses:
            writer.writerow([val])
    
    with open(check_dis_loss, "w") as output:
        writer = csv.writer(output, lineterminator='\n')
        for val in epoch_discriminator_losses:
            writer.writerow([val])
            
    with open(check_gen_loss, "w") as output:
        writer = csv.writer(output, lineterminator='\n')
        for val in epoch_generator_losses:
            writer.writerow([val])
    
    #saved
    print(f"{nl}\
    Saved{nl}")
# Out:
# [LOG 2019-11-08 21:00:10.306381]
# Epoch 0001 / 0500:
#     Reconstruction Loss: 0.0401
#     Discriminator Loss: 1.4988
#     Generator Loss: 0.6843
#     Time Taken: 0:02:46.264067
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 21:02:47.220176]
# Epoch 0002 / 0500:
#     Reconstruction Loss: 0.0270
#     Discriminator Loss: 1.3857
#     Generator Loss: 0.6963
#     Time Taken: 0:02:36.825033
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 21:05:24.839856]
# Epoch 0003 / 0500:
#     Reconstruction Loss: 0.0231
#     Discriminator Loss: 1.3854
#     Generator Loss: 0.6936
#     Time Taken: 0:02:37.575793
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 21:08:03.082805]
# Epoch 0004 / 0500:
#     Reconstruction Loss: 0.0181
#     Discriminator Loss: 1.3852
#     Generator Loss: 0.6937
#     Time Taken: 0:02:38.216019
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 21:10:46.570913]
# Epoch 0005 / 0500:
#     Reconstruction Loss: 0.0167
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6939
#     Time Taken: 0:02:43.457045
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 21:13:34.982678]
# Epoch 0006 / 0500:
#     Reconstruction Loss: 0.0159
#     Discriminator Loss: 1.3844
#     Generator Loss: 0.6942
#     Time Taken: 0:02:48.378852
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 21:16:21.763265]
# Epoch 0007 / 0500:
#     Reconstruction Loss: 0.0154
#     Discriminator Loss: 1.3840
#     Generator Loss: 0.6944
#     Time Taken: 0:02:46.756652
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 21:19:06.319998]
# Epoch 0008 / 0500:
#     Reconstruction Loss: 0.0153
#     Discriminator Loss: 1.3838
#     Generator Loss: 0.6945
#     Time Taken: 0:02:44.530801
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 21:21:57.485927]
# Epoch 0009 / 0500:
#     Reconstruction Loss: 0.0153
#     Discriminator Loss: 1.3838
#     Generator Loss: 0.6945
#     Time Taken: 0:02:51.139001
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 21:24:52.815251]
# Epoch 0010 / 0500:
#     Reconstruction Loss: 0.0153
#     Discriminator Loss: 1.3838
#     Generator Loss: 0.6946
#     Time Taken: 0:02:55.303393
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 21:27:53.110758]
# Epoch 0011 / 0500:
#     Reconstruction Loss: 0.0153
#     Discriminator Loss: 1.3838
#     Generator Loss: 0.6946
#     Time Taken: 0:03:00.270573
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 21:31:00.100936]
# Epoch 0012 / 0500:
#     Reconstruction Loss: 0.0155
#     Discriminator Loss: 1.3839
#     Generator Loss: 0.6946
#     Time Taken: 0:03:06.965242
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 21:34:03.892956]
# Epoch 0013 / 0500:
#     Reconstruction Loss: 0.0156
#     Discriminator Loss: 1.3839
#     Generator Loss: 0.6947
#     Time Taken: 0:03:03.718218
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 21:37:01.978019]
# Epoch 0014 / 0500:
#     Reconstruction Loss: 0.0157
#     Discriminator Loss: 1.3843
#     Generator Loss: 0.6948
#     Time Taken: 0:02:58.058136
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 21:39:59.641589]
# Epoch 0015 / 0500:
#     Reconstruction Loss: 0.0156
#     Discriminator Loss: 1.3846
#     Generator Loss: 0.6943
#     Time Taken: 0:02:57.638637
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 21:43:00.052674]
# Epoch 0016 / 0500:
#     Reconstruction Loss: 0.0158
#     Discriminator Loss: 1.3845
#     Generator Loss: 0.6943
#     Time Taken: 0:03:00.386148
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 21:45:56.576645]
# Epoch 0017 / 0500:
#     Reconstruction Loss: 0.0155
#     Discriminator Loss: 1.3842
#     Generator Loss: 0.6940
#     Time Taken: 0:02:56.499036
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 21:48:53.669520]
# Epoch 0018 / 0500:
#     Reconstruction Loss: 0.0158
#     Discriminator Loss: 1.3841
#     Generator Loss: 0.6943
#     Time Taken: 0:02:57.068939
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 21:51:58.441448]
# Epoch 0019 / 0500:
#     Reconstruction Loss: 0.0210
#     Discriminator Loss: 1.3844
#     Generator Loss: 0.6948
#     Time Taken: 0:03:04.747990
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 21:54:59.159877]
# Epoch 0020 / 0500:
#     Reconstruction Loss: 0.0156
#     Discriminator Loss: 1.3844
#     Generator Loss: 0.6947
#     Time Taken: 0:03:00.693490
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 21:58:00.193369]
# Epoch 0021 / 0500:
#     Reconstruction Loss: 0.0170
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6943
#     Time Taken: 0:03:01.007565
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 22:00:58.721111]
# Epoch 0022 / 0500:
#     Reconstruction Loss: 0.0158
#     Discriminator Loss: 1.3844
#     Generator Loss: 0.6942
#     Time Taken: 0:02:58.460923
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 22:03:56.946187]
# Epoch 0023 / 0500:
#     Reconstruction Loss: 0.0157
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6938
#     Time Taken: 0:02:58.201140
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 22:07:00.895992]
# Epoch 0024 / 0500:
#     Reconstruction Loss: 0.0156
#     Discriminator Loss: 1.3846
#     Generator Loss: 0.6948
#     Time Taken: 0:03:03.921878
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 22:09:53.811739]
# Epoch 0025 / 0500:
#     Reconstruction Loss: 0.0176
#     Discriminator Loss: 1.3842
#     Generator Loss: 0.6947
#     Time Taken: 0:02:52.890813
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 22:12:48.727644]
# Epoch 0026 / 0500:
#     Reconstruction Loss: 0.0155
#     Discriminator Loss: 1.3846
#     Generator Loss: 0.6941
#     Time Taken: 0:02:54.889974
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 22:15:43.054169]
# Epoch 0027 / 0500:
#     Reconstruction Loss: 0.0155
#     Discriminator Loss: 1.3844
#     Generator Loss: 0.6941
#     Time Taken: 0:02:54.300596
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 22:18:33.203825]
# Epoch 0028 / 0500:
#     Reconstruction Loss: 0.0157
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6940
#     Time Taken: 0:02:50.123724
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 22:21:22.988313]
# Epoch 0029 / 0500:
#     Reconstruction Loss: 0.0155
#     Discriminator Loss: 1.3844
#     Generator Loss: 0.6952
#     Time Taken: 0:02:49.755563
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 22:24:15.247812]
# Epoch 0030 / 0500:
#     Reconstruction Loss: 0.0156
#     Discriminator Loss: 1.3846
#     Generator Loss: 0.6937
#     Time Taken: 0:02:52.233568
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 22:27:08.762486]
# Epoch 0031 / 0500:
#     Reconstruction Loss: 0.0156
#     Discriminator Loss: 1.3845
#     Generator Loss: 0.6952
#     Time Taken: 0:02:53.486749
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 22:29:59.741927]
# Epoch 0032 / 0500:
#     Reconstruction Loss: 0.0157
#     Discriminator Loss: 1.3844
#     Generator Loss: 0.6953
#     Time Taken: 0:02:50.952513
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 22:32:51.406981]
# Epoch 0033 / 0500:
#     Reconstruction Loss: 0.0175
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6939
#     Time Taken: 0:02:51.641118
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 22:35:43.644834]
# Epoch 0034 / 0500:
#     Reconstruction Loss: 0.0155
#     Discriminator Loss: 1.3845
#     Generator Loss: 0.6945
#     Time Taken: 0:02:52.208929
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 22:38:32.735345]
# Epoch 0035 / 0500:
#     Reconstruction Loss: 0.0167
#     Discriminator Loss: 1.3846
#     Generator Loss: 0.6938
#     Time Taken: 0:02:49.063584
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 22:41:24.153102]
# Epoch 0036 / 0500:
#     Reconstruction Loss: 0.0267
#     Discriminator Loss: 1.3854
#     Generator Loss: 0.6926
#     Time Taken: 0:02:51.391826
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 22:44:17.150111]
# Epoch 0037 / 0500:
#     Reconstruction Loss: 0.0170
#     Discriminator Loss: 1.3845
#     Generator Loss: 0.6939
#     Time Taken: 0:02:52.970080
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 22:47:09.941892]
# Epoch 0038 / 0500:
#     Reconstruction Loss: 0.0171
#     Discriminator Loss: 1.3850
#     Generator Loss: 0.6955
#     Time Taken: 0:02:52.766847
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 22:50:00.221020]
# Epoch 0039 / 0500:
#     Reconstruction Loss: 0.0160
#     Discriminator Loss: 1.3846
#     Generator Loss: 0.6959
#     Time Taken: 0:02:50.254195
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 22:52:48.412670]
# Epoch 0040 / 0500:
#     Reconstruction Loss: 0.0191
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6940
#     Time Taken: 0:02:48.164720
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 22:55:39.870290]
# Epoch 0041 / 0500:
#     Reconstruction Loss: 0.0181
#     Discriminator Loss: 1.3845
#     Generator Loss: 0.6944
#     Time Taken: 0:02:51.430690
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 22:58:34.180331]
# Epoch 0042 / 0500:
#     Reconstruction Loss: 0.0154
#     Discriminator Loss: 1.3842
#     Generator Loss: 0.6952
#     Time Taken: 0:02:54.285108
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:01:27.478567]
# Epoch 0043 / 0500:
#     Reconstruction Loss: 0.0153
#     Discriminator Loss: 1.3841
#     Generator Loss: 0.6952
#     Time Taken: 0:02:53.270310
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:04:15.484944]
# Epoch 0044 / 0500:
#     Reconstruction Loss: 0.0175
#     Discriminator Loss: 1.3844
#     Generator Loss: 0.6952
#     Time Taken: 0:02:47.980446
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:07:03.267904]
# Epoch 0045 / 0500:
#     Reconstruction Loss: 0.0176
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6960
#     Time Taken: 0:02:47.755032
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:09:49.783165]
# Epoch 0046 / 0500:
#     Reconstruction Loss: 0.0235
#     Discriminator Loss: 1.3844
#     Generator Loss: 0.6954
#     Time Taken: 0:02:46.489331
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:12:36.215786]
# Epoch 0047 / 0500:
#     Reconstruction Loss: 0.0162
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6937
#     Time Taken: 0:02:46.406692
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:15:24.848460]
# Epoch 0048 / 0500:
#     Reconstruction Loss: 0.0152
#     Discriminator Loss: 1.3843
#     Generator Loss: 0.6946
#     Time Taken: 0:02:48.604749
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:18:10.592117]
# Epoch 0049 / 0500:
#     Reconstruction Loss: 0.0158
#     Discriminator Loss: 1.3842
#     Generator Loss: 0.6951
#     Time Taken: 0:02:45.713734
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:20:56.752903]
# Epoch 0050 / 0500:
#     Reconstruction Loss: 0.0158
#     Discriminator Loss: 1.3841
#     Generator Loss: 0.6954
#     Time Taken: 0:02:46.129870
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:23:43.294179]
# Epoch 0051 / 0500:
#     Reconstruction Loss: 0.0150
#     Discriminator Loss: 1.3842
#     Generator Loss: 0.6953
#     Time Taken: 0:02:46.515345
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:26:28.313587]
# Epoch 0052 / 0500:
#     Reconstruction Loss: 0.0156
#     Discriminator Loss: 1.3841
#     Generator Loss: 0.6954
#     Time Taken: 0:02:44.990484
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:29:15.575398]
# Epoch 0053 / 0500:
#     Reconstruction Loss: 0.0151
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6963
#     Time Taken: 0:02:47.235879
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:32:02.182972]
# Epoch 0054 / 0500:
#     Reconstruction Loss: 0.0168
#     Discriminator Loss: 1.3843
#     Generator Loss: 0.6956
#     Time Taken: 0:02:46.577653
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:34:49.740576]
# Epoch 0055 / 0500:
#     Reconstruction Loss: 0.0155
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6933
#     Time Taken: 0:02:47.502752
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:37:36.293826]
# Epoch 0056 / 0500:
#     Reconstruction Loss: 0.0166
#     Discriminator Loss: 1.3842
#     Generator Loss: 0.6950
#     Time Taken: 0:02:46.527316
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:40:22.018256]
# Epoch 0057 / 0500:
#     Reconstruction Loss: 0.0151
#     Discriminator Loss: 1.3842
#     Generator Loss: 0.6952
#     Time Taken: 0:02:45.699497
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:43:07.568659]
# Epoch 0058 / 0500:
#     Reconstruction Loss: 0.0184
#     Discriminator Loss: 1.3841
#     Generator Loss: 0.6952
#     Time Taken: 0:02:45.490563
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:45:54.760702]
# Epoch 0059 / 0500:
#     Reconstruction Loss: 0.0211
#     Discriminator Loss: 1.3841
#     Generator Loss: 0.6954
#     Time Taken: 0:02:47.165113
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:48:42.255922]
# Epoch 0060 / 0500:
#     Reconstruction Loss: 0.0166
#     Discriminator Loss: 1.3840
#     Generator Loss: 0.6954
#     Time Taken: 0:02:47.467296
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:51:30.164839]
# Epoch 0061 / 0500:
#     Reconstruction Loss: 0.0150
#     Discriminator Loss: 1.3842
#     Generator Loss: 0.6953
#     Time Taken: 0:02:47.882989
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:54:17.432238]
# Epoch 0062 / 0500:
#     Reconstruction Loss: 0.0150
#     Discriminator Loss: 1.3841
#     Generator Loss: 0.6954
#     Time Taken: 0:02:47.235482
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:57:07.698594]
# Epoch 0063 / 0500:
#     Reconstruction Loss: 0.0150
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6964
#     Time Taken: 0:02:50.241426
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-08 23:59:57.775047]
# Epoch 0064 / 0500:
#     Reconstruction Loss: 0.0162
#     Discriminator Loss: 1.3841
#     Generator Loss: 0.6966
#     Time Taken: 0:02:50.042540
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 00:02:48.842618]
# Epoch 0065 / 0500:
#     Reconstruction Loss: 0.0198
#     Discriminator Loss: 1.3844
#     Generator Loss: 0.6951
#     Time Taken: 0:02:51.039647
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 00:05:41.012678]
# Epoch 0066 / 0500:
#     Reconstruction Loss: 0.0180
#     Discriminator Loss: 1.3843
#     Generator Loss: 0.6954
#     Time Taken: 0:02:52.142133
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 00:08:29.751668]
# Epoch 0067 / 0500:
#     Reconstruction Loss: 0.0151
#     Discriminator Loss: 1.3844
#     Generator Loss: 0.6953
#     Time Taken: 0:02:48.713060
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 00:11:19.442543]
# Epoch 0068 / 0500:
#     Reconstruction Loss: 0.0150
#     Discriminator Loss: 1.3844
#     Generator Loss: 0.6953
#     Time Taken: 0:02:49.664942
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 00:14:07.319235]
# Epoch 0069 / 0500:
#     Reconstruction Loss: 0.0216
#     Discriminator Loss: 1.3844
#     Generator Loss: 0.6954
#     Time Taken: 0:02:47.849764
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 00:16:55.389459]
# Epoch 0070 / 0500:
#     Reconstruction Loss: 0.0184
#     Discriminator Loss: 1.3845
#     Generator Loss: 0.6954
#     Time Taken: 0:02:48.043296
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 00:19:42.956015]
# Epoch 0071 / 0500:
#     Reconstruction Loss: 0.0216
#     Discriminator Loss: 1.3845
#     Generator Loss: 0.6952
#     Time Taken: 0:02:47.541621
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 00:22:32.435380]
# Epoch 0072 / 0500:
#     Reconstruction Loss: 0.0173
#     Discriminator Loss: 1.3844
#     Generator Loss: 0.6955
#     Time Taken: 0:02:49.451438
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 00:25:19.675888]
# Epoch 0073 / 0500:
#     Reconstruction Loss: 0.0174
#     Discriminator Loss: 1.3845
#     Generator Loss: 0.6955
#     Time Taken: 0:02:47.213577
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 00:28:08.822843]
# Epoch 0074 / 0500:
#     Reconstruction Loss: 0.0149
#     Discriminator Loss: 1.3845
#     Generator Loss: 0.6953
#     Time Taken: 0:02:49.121771
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 00:30:59.538598]
# Epoch 0075 / 0500:
#     Reconstruction Loss: 0.0164
#     Discriminator Loss: 1.3844
#     Generator Loss: 0.6955
#     Time Taken: 0:02:50.683838
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 00:33:50.165452]
# Epoch 0076 / 0500:
#     Reconstruction Loss: 0.0152
#     Discriminator Loss: 1.3844
#     Generator Loss: 0.6955
#     Time Taken: 0:02:50.593946
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 00:36:45.465019]
# Epoch 0077 / 0500:
#     Reconstruction Loss: 0.0155
#     Discriminator Loss: 1.3846
#     Generator Loss: 0.6953
#     Time Taken: 0:02:55.235735
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 00:39:42.724170]
# Epoch 0078 / 0500:
#     Reconstruction Loss: 0.0149
#     Discriminator Loss: 1.3845
#     Generator Loss: 0.6955
#     Time Taken: 0:02:57.228232
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 00:42:39.337574]
# Epoch 0079 / 0500:
#     Reconstruction Loss: 0.0200
#     Discriminator Loss: 1.3845
#     Generator Loss: 0.6956
#     Time Taken: 0:02:56.583479
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 00:45:38.322633]
# Epoch 0080 / 0500:
#     Reconstruction Loss: 0.0163
#     Discriminator Loss: 1.3845
#     Generator Loss: 0.6955
#     Time Taken: 0:02:58.955142
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 00:48:32.481605]
# Epoch 0081 / 0500:
#     Reconstruction Loss: 0.0176
#     Discriminator Loss: 1.3845
#     Generator Loss: 0.6954
#     Time Taken: 0:02:54.127055
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 00:51:28.245669]
# Epoch 0082 / 0500:
#     Reconstruction Loss: 0.0163
#     Discriminator Loss: 1.3845
#     Generator Loss: 0.6955
#     Time Taken: 0:02:55.736138
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 00:54:25.409056]
# Epoch 0083 / 0500:
#     Reconstruction Loss: 0.0154
#     Discriminator Loss: 1.3845
#     Generator Loss: 0.6954
#     Time Taken: 0:02:57.134463
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 00:57:27.265475]
# Epoch 0084 / 0500:
#     Reconstruction Loss: 0.0147
#     Discriminator Loss: 1.3846
#     Generator Loss: 0.6953
#     Time Taken: 0:03:01.829489
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 01:00:27.792259]
# Epoch 0085 / 0500:
#     Reconstruction Loss: 0.0180
#     Discriminator Loss: 1.3846
#     Generator Loss: 0.6953
#     Time Taken: 0:03:00.499854
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 01:03:30.239044]
# Epoch 0086 / 0500:
#     Reconstruction Loss: 0.0163
#     Discriminator Loss: 1.3845
#     Generator Loss: 0.6954
#     Time Taken: 0:03:02.416865
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 01:06:34.630451]
# Epoch 0087 / 0500:
#     Reconstruction Loss: 0.0156
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:03:04.363481
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 01:09:40.189456]
# Epoch 0088 / 0500:
#     Reconstruction Loss: 0.0151
#     Discriminator Loss: 1.3846
#     Generator Loss: 0.6953
#     Time Taken: 0:03:05.529085
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 01:12:36.869167]
# Epoch 0089 / 0500:
#     Reconstruction Loss: 0.0181
#     Discriminator Loss: 1.3845
#     Generator Loss: 0.6955
#     Time Taken: 0:02:56.648791
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 01:15:31.736640]
# Epoch 0090 / 0500:
#     Reconstruction Loss: 0.0159
#     Discriminator Loss: 1.3845
#     Generator Loss: 0.6956
#     Time Taken: 0:02:54.841542
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 01:18:21.968566]
# Epoch 0091 / 0500:
#     Reconstruction Loss: 0.0147
#     Discriminator Loss: 1.3845
#     Generator Loss: 0.6955
#     Time Taken: 0:02:50.205997
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 01:21:12.020989]
# Epoch 0092 / 0500:
#     Reconstruction Loss: 0.0154
#     Discriminator Loss: 1.3846
#     Generator Loss: 0.6954
#     Time Taken: 0:02:50.022501
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 01:24:01.369666]
# Epoch 0093 / 0500:
#     Reconstruction Loss: 0.0182
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:49.318755
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 01:26:51.758211]
# Epoch 0094 / 0500:
#     Reconstruction Loss: 0.0164
#     Discriminator Loss: 1.3846
#     Generator Loss: 0.6954
#     Time Taken: 0:02:50.360621
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 01:29:44.585235]
# Epoch 0095 / 0500:
#     Reconstruction Loss: 0.0157
#     Discriminator Loss: 1.3846
#     Generator Loss: 0.6954
#     Time Taken: 0:02:52.798099
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 01:32:39.817070]
# Epoch 0096 / 0500:
#     Reconstruction Loss: 0.0152
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6954
#     Time Taken: 0:02:55.174987
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 01:35:36.557926]
# Epoch 0097 / 0500:
#     Reconstruction Loss: 0.0148
#     Discriminator Loss: 1.3846
#     Generator Loss: 0.6955
#     Time Taken: 0:02:56.710936
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 01:38:32.008893]
# Epoch 0098 / 0500:
#     Reconstruction Loss: 0.0159
#     Discriminator Loss: 1.3845
#     Generator Loss: 0.6955
#     Time Taken: 0:02:55.425036
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 01:41:29.004282]
# Epoch 0099 / 0500:
#     Reconstruction Loss: 0.0145
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:56.939539
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 01:44:29.179858]
# Epoch 0100 / 0500:
#     Reconstruction Loss: 0.0146
#     Discriminator Loss: 1.3846
#     Generator Loss: 0.6955
#     Time Taken: 0:03:00.147649
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 01:47:30.809335]
# Epoch 0101 / 0500:
#     Reconstruction Loss: 0.0171
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:03:01.600554
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 01:50:32.015441]
# Epoch 0102 / 0500:
#     Reconstruction Loss: 0.0165
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6955
#     Time Taken: 0:03:01.178181
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 01:53:30.015143]
# Epoch 0103 / 0500:
#     Reconstruction Loss: 0.0176
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:57.972775
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 01:56:27.305716]
# Epoch 0104 / 0500:
#     Reconstruction Loss: 0.0171
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:57.263644
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 01:59:27.205623]
# Epoch 0105 / 0500:
#     Reconstruction Loss: 0.0180
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:59.845055
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 02:02:31.293059]
# Epoch 0106 / 0500:
#     Reconstruction Loss: 0.0145
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6955
#     Time Taken: 0:03:04.059511
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 02:05:34.600031]
# Epoch 0107 / 0500:
#     Reconstruction Loss: 0.0156
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6954
#     Time Taken: 0:03:03.281040
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 02:08:36.725780]
# Epoch 0108 / 0500:
#     Reconstruction Loss: 0.0155
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6955
#     Time Taken: 0:03:02.101814
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 02:11:39.831297]
# Epoch 0109 / 0500:
#     Reconstruction Loss: 0.0168
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6951
#     Time Taken: 0:03:03.077590
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 02:14:40.869857]
# Epoch 0110 / 0500:
#     Reconstruction Loss: 0.0170
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6954
#     Time Taken: 0:03:01.011634
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 02:17:40.570687]
# Epoch 0111 / 0500:
#     Reconstruction Loss: 0.0154
#     Discriminator Loss: 1.3846
#     Generator Loss: 0.6955
#     Time Taken: 0:02:59.671906
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 02:20:40.940501]
# Epoch 0112 / 0500:
#     Reconstruction Loss: 0.0148
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:03:00.342886
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 02:23:41.511316]
# Epoch 0113 / 0500:
#     Reconstruction Loss: 0.0162
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:03:00.542891
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 02:26:41.960940]
# Epoch 0114 / 0500:
#     Reconstruction Loss: 0.0155
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:03:00.421696
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 02:29:40.724627]
# Epoch 0115 / 0500:
#     Reconstruction Loss: 0.0160
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:58.734766
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 02:32:39.261832]
# Epoch 0116 / 0500:
#     Reconstruction Loss: 0.0158
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:58.509281
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 02:35:38.433393]
# Epoch 0117 / 0500:
#     Reconstruction Loss: 0.0143
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:59.144631
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 02:38:37.744792]
# Epoch 0118 / 0500:
#     Reconstruction Loss: 0.0158
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6954
#     Time Taken: 0:02:59.284471
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 02:41:37.686802]
# Epoch 0119 / 0500:
#     Reconstruction Loss: 0.0159
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6955
#     Time Taken: 0:02:59.911092
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 02:44:34.566019]
# Epoch 0120 / 0500:
#     Reconstruction Loss: 0.0185
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6954
#     Time Taken: 0:02:56.845308
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 02:47:29.554691]
# Epoch 0121 / 0500:
#     Reconstruction Loss: 0.0165
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6954
#     Time Taken: 0:02:54.952769
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 02:50:25.794670]
# Epoch 0122 / 0500:
#     Reconstruction Loss: 0.0189
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:56.182135
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 02:53:22.543228]
# Epoch 0123 / 0500:
#     Reconstruction Loss: 0.0150
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6952
#     Time Taken: 0:02:56.678745
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 02:56:19.517750]
# Epoch 0124 / 0500:
#     Reconstruction Loss: 0.0144
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:56.944600
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 02:59:15.281121]
# Epoch 0125 / 0500:
#     Reconstruction Loss: 0.0142
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:55.734448
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 03:02:10.905614]
# Epoch 0126 / 0500:
#     Reconstruction Loss: 0.0154
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6954
#     Time Taken: 0:02:55.594572
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 03:05:07.201885]
# Epoch 0127 / 0500:
#     Reconstruction Loss: 0.0183
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:56.267348
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 03:08:01.900215]
# Epoch 0128 / 0500:
#     Reconstruction Loss: 0.0144
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:54.606575
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 03:10:55.512112]
# Epoch 0129 / 0500:
#     Reconstruction Loss: 0.0184
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6951
#     Time Taken: 0:02:53.578985
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 03:13:47.845643]
# Epoch 0130 / 0500:
#     Reconstruction Loss: 0.0211
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6954
#     Time Taken: 0:02:52.303609
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 03:16:40.746780]
# Epoch 0131 / 0500:
#     Reconstruction Loss: 0.0141
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:52.867226
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 03:19:32.965332]
# Epoch 0132 / 0500:
#     Reconstruction Loss: 0.0209
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6955
#     Time Taken: 0:02:52.160703
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 03:22:26.035137]
# Epoch 0133 / 0500:
#     Reconstruction Loss: 0.0155
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:53.042877
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 03:25:18.940916]
# Epoch 0134 / 0500:
#     Reconstruction Loss: 0.0175
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6954
#     Time Taken: 0:02:52.878852
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 03:28:10.820812]
# Epoch 0135 / 0500:
#     Reconstruction Loss: 0.0143
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:51.852967
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 03:31:03.899599]
# Epoch 0136 / 0500:
#     Reconstruction Loss: 0.0143
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6954
#     Time Taken: 0:02:53.009967
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 03:33:56.233907]
# Epoch 0137 / 0500:
#     Reconstruction Loss: 0.0140
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:52.306382
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 03:36:48.406936]
# Epoch 0138 / 0500:
#     Reconstruction Loss: 0.0197
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:52.143107
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 03:39:40.564236]
# Epoch 0139 / 0500:
#     Reconstruction Loss: 0.0158
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:52.127378
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 03:42:31.754129]
# Epoch 0140 / 0500:
#     Reconstruction Loss: 0.0163
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:51.160971
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 03:45:22.544038]
# Epoch 0141 / 0500:
#     Reconstruction Loss: 0.0155
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6954
#     Time Taken: 0:02:50.758989
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 03:48:11.514840]
# Epoch 0142 / 0500:
#     Reconstruction Loss: 0.0151
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:48.911959
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 03:51:00.113660]
# Epoch 0143 / 0500:
#     Reconstruction Loss: 0.0162
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:48.544962
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 03:53:48.696453]
# Epoch 0144 / 0500:
#     Reconstruction Loss: 0.0141
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6955
#     Time Taken: 0:02:48.554866
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 03:56:36.861413]
# Epoch 0145 / 0500:
#     Reconstruction Loss: 0.0137
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6955
#     Time Taken: 0:02:48.136037
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 03:59:25.385632]
# Epoch 0146 / 0500:
#     Reconstruction Loss: 0.0163
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:48.498288
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:02:13.206240]
# Epoch 0147 / 0500:
#     Reconstruction Loss: 0.0160
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6952
#     Time Taken: 0:02:47.791687
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:04:59.783412]
# Epoch 0148 / 0500:
#     Reconstruction Loss: 0.0146
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6954
#     Time Taken: 0:02:46.523312
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:07:46.925063]
# Epoch 0149 / 0500:
#     Reconstruction Loss: 0.0139
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:47.114730
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:10:32.566260]
# Epoch 0150 / 0500:
#     Reconstruction Loss: 0.0153
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6951
#     Time Taken: 0:02:45.578367
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:13:17.960073]
# Epoch 0151 / 0500:
#     Reconstruction Loss: 0.0165
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:45.362893
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:16:04.692862]
# Epoch 0152 / 0500:
#     Reconstruction Loss: 0.0137
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:46.676939
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:18:49.806954]
# Epoch 0153 / 0500:
#     Reconstruction Loss: 0.0176
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:45.061234
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:21:34.131532]
# Epoch 0154 / 0500:
#     Reconstruction Loss: 0.0138
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6954
#     Time Taken: 0:02:44.267731
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:24:17.468876]
# Epoch 0155 / 0500:
#     Reconstruction Loss: 0.0136
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6954
#     Time Taken: 0:02:43.303433
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:27:00.384088]
# Epoch 0156 / 0500:
#     Reconstruction Loss: 0.0137
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:42.885292
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:29:42.836467]
# Epoch 0157 / 0500:
#     Reconstruction Loss: 0.0196
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:42.396531
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:32:25.254847]
# Epoch 0158 / 0500:
#     Reconstruction Loss: 0.0140
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:42.390456
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:35:11.090990]
# Epoch 0159 / 0500:
#     Reconstruction Loss: 0.0160
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6954
#     Time Taken: 0:02:45.806224
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:37:59.013560]
# Epoch 0160 / 0500:
#     Reconstruction Loss: 0.0137
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6954
#     Time Taken: 0:02:47.873701
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:40:41.528832]
# Epoch 0161 / 0500:
#     Reconstruction Loss: 0.0138
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:42.486349
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:43:24.236307]
# Epoch 0162 / 0500:
#     Reconstruction Loss: 0.0144
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:42.650624
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:46:07.552201]
# Epoch 0163 / 0500:
#     Reconstruction Loss: 0.0151
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6954
#     Time Taken: 0:02:43.258048
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:48:51.203266]
# Epoch 0164 / 0500:
#     Reconstruction Loss: 0.0140
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6954
#     Time Taken: 0:02:43.623138
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:51:34.680217]
# Epoch 0165 / 0500:
#     Reconstruction Loss: 0.0157
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:43.447017
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:54:17.824556]
# Epoch 0166 / 0500:
#     Reconstruction Loss: 0.0143
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6954
#     Time Taken: 0:02:43.090497
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:57:07.161877]
# Epoch 0167 / 0500:
#     Reconstruction Loss: 0.0178
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6954
#     Time Taken: 0:02:49.308399
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 04:59:49.504893]
# Epoch 0168 / 0500:
#     Reconstruction Loss: 0.0163
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6954
#     Time Taken: 0:02:42.316087
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 05:02:32.428764]
# Epoch 0169 / 0500:
#     Reconstruction Loss: 0.0149
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:42.894947
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 05:05:15.452947]
# Epoch 0170 / 0500:
#     Reconstruction Loss: 0.0145
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6954
#     Time Taken: 0:02:42.995256
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 05:08:00.111065]
# Epoch 0171 / 0500:
#     Reconstruction Loss: 0.0144
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:44.630194
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 05:10:44.268455]
# Epoch 0172 / 0500:
#     Reconstruction Loss: 0.0151
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:44.126471
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 05:13:28.228139]
# Epoch 0173 / 0500:
#     Reconstruction Loss: 0.0141
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:43.932755
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 05:16:12.161959]
# Epoch 0174 / 0500:
#     Reconstruction Loss: 0.0156
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6952
#     Time Taken: 0:02:43.905896
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 05:18:55.458900]
# Epoch 0175 / 0500:
#     Reconstruction Loss: 0.0141
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6952
#     Time Taken: 0:02:43.267019
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 05:21:39.422099]
# Epoch 0176 / 0500:
#     Reconstruction Loss: 0.0162
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6952
#     Time Taken: 0:02:43.934276
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 05:24:23.866972]
# Epoch 0177 / 0500:
#     Reconstruction Loss: 0.0134
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6953
#     Time Taken: 0:02:44.413953
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 05:27:07.784277]
# Epoch 0178 / 0500:
#     Reconstruction Loss: 0.0134
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:43.888381
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 05:29:52.679781]
# Epoch 0179 / 0500:
#     Reconstruction Loss: 0.0147
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:44.865581
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 05:32:37.533632]
# Epoch 0180 / 0500:
#     Reconstruction Loss: 0.0134
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6952
#     Time Taken: 0:02:44.824930
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 05:35:22.395202]
# Epoch 0181 / 0500:
#     Reconstruction Loss: 0.0133
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:44.833643
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 05:38:07.724586]
# Epoch 0182 / 0500:
#     Reconstruction Loss: 0.0133
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6954
#     Time Taken: 0:02:45.300463
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 05:40:53.125198]
# Epoch 0183 / 0500:
#     Reconstruction Loss: 0.0167
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6953
#     Time Taken: 0:02:45.371690
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 05:43:39.290496]
# Epoch 0184 / 0500:
#     Reconstruction Loss: 0.0141
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:46.136372
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 05:46:26.311950]
# Epoch 0185 / 0500:
#     Reconstruction Loss: 0.0156
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6954
#     Time Taken: 0:02:46.994525
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 05:49:14.377041]
# Epoch 0186 / 0500:
#     Reconstruction Loss: 0.0151
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6952
#     Time Taken: 0:02:48.036169
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 05:52:02.284655]
# Epoch 0187 / 0500:
#     Reconstruction Loss: 0.0136
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6953
#     Time Taken: 0:02:47.862734
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 05:54:49.723060]
# Epoch 0188 / 0500:
#     Reconstruction Loss: 0.0139
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6955
#     Time Taken: 0:02:47.409483
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 05:57:36.804169]
# Epoch 0189 / 0500:
#     Reconstruction Loss: 0.0143
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:47.051186
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:00:24.936218]
# Epoch 0190 / 0500:
#     Reconstruction Loss: 0.0138
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6952
#     Time Taken: 0:02:48.104123
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:03:12.917513]
# Epoch 0191 / 0500:
#     Reconstruction Loss: 0.0132
#     Discriminator Loss: 1.3850
#     Generator Loss: 0.6950
#     Time Taken: 0:02:47.953370
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:06:01.511819]
# Epoch 0192 / 0500:
#     Reconstruction Loss: 0.0132
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6953
#     Time Taken: 0:02:48.562391
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:08:50.836313]
# Epoch 0193 / 0500:
#     Reconstruction Loss: 0.0131
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6953
#     Time Taken: 0:02:49.296568
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:11:40.152236]
# Epoch 0194 / 0500:
#     Reconstruction Loss: 0.0132
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:49.287999
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:14:30.122650]
# Epoch 0195 / 0500:
#     Reconstruction Loss: 0.0141
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6953
#     Time Taken: 0:02:49.943484
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:17:19.499330]
# Epoch 0196 / 0500:
#     Reconstruction Loss: 0.0137
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:49.315846
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:20:09.034648]
# Epoch 0197 / 0500:
#     Reconstruction Loss: 0.0152
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6952
#     Time Taken: 0:02:49.506394
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:22:58.307570]
# Epoch 0198 / 0500:
#     Reconstruction Loss: 0.0131
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:49.244002
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:25:48.532539]
# Epoch 0199 / 0500:
#     Reconstruction Loss: 0.0160
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6954
#     Time Taken: 0:02:50.196046
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:28:37.617024]
# Epoch 0200 / 0500:
#     Reconstruction Loss: 0.0136
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6954
#     Time Taken: 0:02:49.051571
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:31:26.937860]
# Epoch 0201 / 0500:
#     Reconstruction Loss: 0.0142
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6952
#     Time Taken: 0:02:49.291912
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:34:15.982441]
# Epoch 0202 / 0500:
#     Reconstruction Loss: 0.0138
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:49.015658
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:37:05.523186]
# Epoch 0203 / 0500:
#     Reconstruction Loss: 0.0132
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6951
#     Time Taken: 0:02:49.510822
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:39:56.528727]
# Epoch 0204 / 0500:
#     Reconstruction Loss: 0.0143
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6955
#     Time Taken: 0:02:50.974625
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:42:47.557041]
# Epoch 0205 / 0500:
#     Reconstruction Loss: 0.0130
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6952
#     Time Taken: 0:02:50.999390
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:45:37.467208]
# Epoch 0206 / 0500:
#     Reconstruction Loss: 0.0129
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6954
#     Time Taken: 0:02:49.881244
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:48:29.047567]
# Epoch 0207 / 0500:
#     Reconstruction Loss: 0.0141
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6955
#     Time Taken: 0:02:51.548442
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:51:18.681463]
# Epoch 0208 / 0500:
#     Reconstruction Loss: 0.0131
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6954
#     Time Taken: 0:02:49.604973
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:54:07.993323]
# Epoch 0209 / 0500:
#     Reconstruction Loss: 0.0131
#     Discriminator Loss: 1.3850
#     Generator Loss: 0.6950
#     Time Taken: 0:02:49.281941
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:56:59.398650]
# Epoch 0210 / 0500:
#     Reconstruction Loss: 0.0132
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6954
#     Time Taken: 0:02:51.374411
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 06:59:49.717821]
# Epoch 0211 / 0500:
#     Reconstruction Loss: 0.0130
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6952
#     Time Taken: 0:02:50.290246
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 07:02:39.351621]
# Epoch 0212 / 0500:
#     Reconstruction Loss: 0.0130
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6953
#     Time Taken: 0:02:49.605875
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 07:05:28.171866]
# Epoch 0213 / 0500:
#     Reconstruction Loss: 0.0137
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6951
#     Time Taken: 0:02:48.790323
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 07:08:17.251342]
# Epoch 0214 / 0500:
#     Reconstruction Loss: 0.0130
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6952
#     Time Taken: 0:02:49.050553
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 07:11:04.490801]
# Epoch 0215 / 0500:
#     Reconstruction Loss: 0.0131
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6955
#     Time Taken: 0:02:47.208542
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 07:13:51.164916]
# Epoch 0216 / 0500:
#     Reconstruction Loss: 0.0129
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:46.645190
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 07:16:38.816433]
# Epoch 0217 / 0500:
#     Reconstruction Loss: 0.0130
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6953
#     Time Taken: 0:02:47.619602
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 07:19:26.473215]
# Epoch 0218 / 0500:
#     Reconstruction Loss: 0.0143
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6953
#     Time Taken: 0:02:47.627859
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 07:22:16.010240]
# Epoch 0219 / 0500:
#     Reconstruction Loss: 0.0129
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6952
#     Time Taken: 0:02:49.507107
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 07:25:04.181158]
# Epoch 0220 / 0500:
#     Reconstruction Loss: 0.0130
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6953
#     Time Taken: 0:02:48.143990
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 07:27:52.360889]
# Epoch 0221 / 0500:
# ...
#     Time Taken: 0:02:46.727279
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 17:03:33.045364]
# Epoch 0428 / 0500:
#     Reconstruction Loss: 0.0261
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6953
#     Time Taken: 0:02:47.260558
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 17:06:20.860723]
# Epoch 0429 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:47.782447
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 17:09:07.702282]
# Epoch 0430 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:46.806651
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 17:11:53.626183]
# Epoch 0431 / 0500:
#     Reconstruction Loss: 0.0125
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:45.886997
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 17:14:39.058428]
# Epoch 0432 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:45.363430
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 17:17:25.050162]
# Epoch 0433 / 0500:
#     Reconstruction Loss: 0.0124
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:45.954831
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 17:20:10.489347]
# Epoch 0434 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:45.375354
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 17:22:55.425656]
# Epoch 0435 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6951
#     Time Taken: 0:02:44.902398
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 17:25:41.684206]
# Epoch 0436 / 0500:
#     Reconstruction Loss: 0.0131
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:46.223642
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 17:28:27.434613]
# Epoch 0437 / 0500:
#     Reconstruction Loss: 0.0136
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6954
#     Time Taken: 0:02:45.691565
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 17:31:12.772762]
# Epoch 0438 / 0500:
#     Reconstruction Loss: 0.0129
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:45.304237
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 17:33:57.590191]
# Epoch 0439 / 0500:
#     Reconstruction Loss: 0.0125
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:44.777534
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 17:36:42.745120]
# Epoch 0440 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:45.122018
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 17:39:27.199969]
# Epoch 0441 / 0500:
#     Reconstruction Loss: 0.0125
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:44.419940
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 17:42:12.495374]
# Epoch 0442 / 0500:
#     Reconstruction Loss: 0.0125
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6954
#     Time Taken: 0:02:45.228585
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 17:44:57.386658]
# Epoch 0443 / 0500:
#     Reconstruction Loss: 0.0176
#     Discriminator Loss: 1.3849
#     Generator Loss: 0.6951
#     Time Taken: 0:02:44.841416
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 17:47:42.641831]
# Epoch 0444 / 0500:
#     Reconstruction Loss: 0.0289
#     Discriminator Loss: 1.3850
#     Generator Loss: 0.6951
#     Time Taken: 0:02:45.218271
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 17:50:28.124482]
# Epoch 0445 / 0500:
#     Reconstruction Loss: 0.0204
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:45.425797
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 17:53:14.881141]
# Epoch 0446 / 0500:
#     Reconstruction Loss: 0.0133
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:46.722752
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 17:56:00.877358]
# Epoch 0447 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:45.935381
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 17:58:47.942778]
# Epoch 0448 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6951
#     Time Taken: 0:02:47.000593
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:01:34.547924]
# Epoch 0449 / 0500:
#     Reconstruction Loss: 0.0125
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:46.571235
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:04:21.013867]
# Epoch 0450 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6951
#     Time Taken: 0:02:46.433032
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:07:08.585402]
# Epoch 0451 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:47.537626
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:09:56.788291]
# Epoch 0452 / 0500:
#     Reconstruction Loss: 0.0125
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:48.139059
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:12:43.869128]
# Epoch 0453 / 0500:
#     Reconstruction Loss: 0.0125
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:47.036952
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:15:29.795054]
# Epoch 0454 / 0500:
#     Reconstruction Loss: 0.0125
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:45.893014
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:18:16.065050]
# Epoch 0455 / 0500:
#     Reconstruction Loss: 0.0127
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6951
#     Time Taken: 0:02:46.227108
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:21:02.204906]
# Epoch 0456 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:46.076026
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:23:48.541759]
# Epoch 0457 / 0500:
#     Reconstruction Loss: 0.0134
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:46.301945
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:26:35.396198]
# Epoch 0458 / 0500:
#     Reconstruction Loss: 0.0125
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:46.790609
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:29:22.573248]
# Epoch 0459 / 0500:
#     Reconstruction Loss: 0.0125
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:47.114217
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:32:08.796510]
# Epoch 0460 / 0500:
#     Reconstruction Loss: 0.0125
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:46.184367
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:34:54.438190]
# Epoch 0461 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:45.605773
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:37:40.561087]
# Epoch 0462 / 0500:
#     Reconstruction Loss: 0.0125
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:46.082007
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:40:26.358835]
# Epoch 0463 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3846
#     Generator Loss: 0.6955
#     Time Taken: 0:02:45.761842
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:43:12.475736]
# Epoch 0464 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:46.080000
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:45:58.558464]
# Epoch 0465 / 0500:
#     Reconstruction Loss: 0.0125
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6951
#     Time Taken: 0:02:46.019896
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:48:45.214190]
# Epoch 0466 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6952
#     Time Taken: 0:02:46.619821
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:51:31.874024]
# Epoch 0467 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6952
#     Time Taken: 0:02:46.593014
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:54:17.062941]
# Epoch 0468 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3846
#     Generator Loss: 0.6955
#     Time Taken: 0:02:45.156004
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:57:03.472072]
# Epoch 0469 / 0500:
#     Reconstruction Loss: 0.0125
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6954
#     Time Taken: 0:02:46.374221
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 18:59:49.797292]
# Epoch 0470 / 0500:
#     Reconstruction Loss: 0.0125
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6952
#     Time Taken: 0:02:46.291311
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 19:02:36.450774]
# Epoch 0471 / 0500:
#     Reconstruction Loss: 0.0127
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:46.586660
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 19:05:22.957137]
# Epoch 0472 / 0500:
#     Reconstruction Loss: 0.0127
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6951
#     Time Taken: 0:02:46.445525
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 19:08:10.003095]
# Epoch 0473 / 0500:
#     Reconstruction Loss: 0.0128
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:47.006546
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 19:10:57.679080]
# Epoch 0474 / 0500:
#     Reconstruction Loss: 0.0129
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:47.642075
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 19:13:44.053147]
# Epoch 0475 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6951
#     Time Taken: 0:02:46.337164
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 19:16:30.662774]
# Epoch 0476 / 0500:
#     Reconstruction Loss: 0.0151
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6954
#     Time Taken: 0:02:46.573723
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 19:19:18.135607]
# Epoch 0477 / 0500:
#     Reconstruction Loss: 0.0127
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6954
#     Time Taken: 0:02:47.438922
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 19:22:05.638792]
# Epoch 0478 / 0500:
#     Reconstruction Loss: 0.0127
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:47.456308
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 19:24:52.387546]
# Epoch 0479 / 0500:
#     Reconstruction Loss: 0.0129
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6952
#     Time Taken: 0:02:46.709858
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 19:27:38.529403]
# Epoch 0480 / 0500:
#     Reconstruction Loss: 0.0125
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:46.104955
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 19:30:24.992421]
# Epoch 0481 / 0500:
#     Reconstruction Loss: 0.0127
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6951
#     Time Taken: 0:02:46.425120
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 19:33:11.587605]
# Epoch 0482 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6951
#     Time Taken: 0:02:46.558281
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 19:35:58.660224]
# Epoch 0483 / 0500:
#     Reconstruction Loss: 0.0128
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6954
#     Time Taken: 0:02:47.006791
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 19:38:45.491086]
# Epoch 0484 / 0500:
#     Reconstruction Loss: 0.0125
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6954
#     Time Taken: 0:02:46.792964
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 19:41:31.687773]
# Epoch 0485 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:46.132856
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 19:44:18.378160]
# Epoch 0486 / 0500:
#     Reconstruction Loss: 0.0129
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:46.655479
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 19:47:04.642205]
# Epoch 0487 / 0500:
#     Reconstruction Loss: 0.0127
#     Discriminator Loss: 1.3846
#     Generator Loss: 0.6955
#     Time Taken: 0:02:46.203208
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 19:49:49.621486]
# Epoch 0488 / 0500:
#     Reconstruction Loss: 0.0130
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:44.946369
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 19:52:36.095471]
# Epoch 0489 / 0500:
#     Reconstruction Loss: 0.0128
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:46.437082
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 19:55:22.106313]
# Epoch 0490 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:45.977928
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 19:58:08.688205]
# Epoch 0491 / 0500:
#     Reconstruction Loss: 0.0129
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6954
#     Time Taken: 0:02:46.546984
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 20:00:55.068975]
# Epoch 0492 / 0500:
#     Reconstruction Loss: 0.0126
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6951
#     Time Taken: 0:02:46.314947
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 20:03:41.364861]
# Epoch 0493 / 0500:
#     Reconstruction Loss: 0.0138
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6953
#     Time Taken: 0:02:46.260977
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 20:06:27.083801]
# Epoch 0494 / 0500:
#     Reconstruction Loss: 0.0136
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6952
#     Time Taken: 0:02:45.653116
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 20:09:12.712021]
# Epoch 0495 / 0500:
#     Reconstruction Loss: 0.0127
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:45.585802
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 20:11:58.382090]
# Epoch 0496 / 0500:
#     Reconstruction Loss: 0.0226
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6954
#     Time Taken: 0:02:45.633165
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 20:14:45.668741]
# Epoch 0497 / 0500:
#     Reconstruction Loss: 0.0135
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6953
#     Time Taken: 0:02:47.219829
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 20:17:31.848497]
# Epoch 0498 / 0500:
#     Reconstruction Loss: 0.0128
#     Discriminator Loss: 1.3847
#     Generator Loss: 0.6952
#     Time Taken: 0:02:46.143851
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 20:20:16.276918]
# Epoch 0499 / 0500:
#     Reconstruction Loss: 0.0129
#     Discriminator Loss: 1.3848
#     Generator Loss: 0.6951
#     Time Taken: 0:02:44.392513
#
#     Saving checkpoint . . .
#
#     Saved
#
# [LOG 2019-11-09 20:23:02.046321]
# Epoch 0500 / 0500:
#     Reconstruction Loss: 0.0139
#     Discriminator Loss: 1.3846
#     Generator Loss: 0.6954
#     Time Taken: 0:02:45.713553
#
#     Saving checkpoint . . .
#
#     Saved

# %%
epoch_reconstruction_losses.index(min(epoch_reconstruction_losses))
# Out:
# 432

# %%
log()
# plot the reconstruction loss per training epoch
plt.figure(figsize=(16,9))
plt.plot(range(1, len(epoch_reconstruction_losses)+1), epoch_reconstruction_losses)

# set plot title
plt.title(f'{len(epoch_reconstruction_losses)}',fontsize=30)
plt.xticks(np.arange(0,501,20))

# set plot axis labels
plt.xlabel('training epochs')
plt.ylabel('reconstruction loss')
# Out:
# [LOG 2019-11-09 22:45:49.231997]
# Text(0, 0.5, 'reconstruction loss')

# %%
log()
# plot the discriminator loss per training epoch
plt.figure(figsize=(16,9))
plt.plot(range(1, len(epoch_discriminator_losses)+1), epoch_discriminator_losses)

# set plot title
plt.title('AAE training performance')

# set plot axis labels
plt.xlabel('training epochs')
plt.ylabel('discrimination loss')
# Out:
# [LOG 2019-11-09 20:23:02.871561]
# Text(0, 0.5, 'discrimination loss')

# %%
log()
# plot the generator loss per training epoch
plt.figure(figsize=(16,9))
plt.plot(range(1, len(epoch_generator_losses)+1), epoch_generator_losses)

# set plot title
plt.title('AAE training performance')

# set plot axis labels
plt.xlabel('training epochs')
plt.ylabel('generation loss')
# Out:
# [LOG 2019-11-09 20:23:03.189710]
# Text(0, 0.5, 'generation loss')
